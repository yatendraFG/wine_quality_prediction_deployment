# %%
import streamlit as st
import pandas as pd
import pickle

# %%
df = pd.read_csv(r'C:\Users\Lenovo\Desktop\powerbi\winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
X = df.drop('quality', axis =1)
y = df['quality']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model=RandomForestRegressor()
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([6.88, 5.74, 6.89, 5.53, 4.95, 5.1 , 5.14, 6.61, 6.65, 5.91, 4.71,
#        5.21, 5.45, 5.01, 5.17, 5.34, 6.5 , 5.92, 5.76, 5.12, 5.55, 6.56,
#        5.91, 6.04, 4.96, 6.45, 6.36, 5.74, 5.73, 5.13, 6.18, 5.48, 5.17,
#        6.59, 5.13, 4.84, 5.68, 5.17, 6.02, 5.56, 5.74, 5.16, 5.72, 5.33,
#        5.33, 5.04, 5.3 , 5.56, 5.83, 5.28, 5.91, 5.45, 5.02, 6.65, 5.36,
#        5.03, 5.  , 5.62, 5.14, 5.82, 5.11, 6.71, 6.19, 6.  , 5.1 , 5.41,
#        4.55, 5.78, 5.12, 5.87, 5.35, 5.26, 6.  , 6.  , 5.73, 5.81, 4.9 ,
#        5.06, 5.79, 5.92, 5.56, 5.09, 6.74, 4.95, 6.66, 5.8 , 5.9 , 6.55,
#        5.85, 5.05, 5.18, 6.25, 5.9 , 5.03, 5.4 , 5.65, 6.88, 6.1 , 5.1 ,
#        6.04, 5.52, 5.08, 4.98, 5.01, 5.88, 4.84, 6.03, 5.45, 5.01, 5.51,
#        6.04, 5.48, 5.63, 5.57, 5.41, 5.14, 6.18, 6.18, 5.03, 5.7 , 4.99,
#        5.41, 5.23, 5.29, 5.97, 5.37, 5.07, 5.1 , 5.1 , 5.63, 5.37, 5.2 ,
#        5.05, 5.07, 5.98, 5.69, 5.27, 5.64, 6.24, 6.47, 5.75, 6.45, 5.05,
#        5.38, 5.11, 5.21, 6.48, 5.68, 4.23, 6.09, 6.25, 5.13, 4.87, 5.25,
#        6.04, 6.26, 4.95, 5.98, 5.62, 6.36, 5.58, 6.25, 5.01, 5.28, 5.39,
#        4.82, 5.53, 5.2 , 5.1 , 5.58, 5.67, 5.05, 5.5 , 6.35, 5.35, 5.81,
#        5.64, 5.77, 4.95, 5.15, 5.04, 5.21, 5.1 , 5.08, 4.7 , 4.91, 5.67,
#        5.75, 5.2 , 5.36, 5.8 , 4.64, 5.94, 5.68, 5.52, 5.65, 5.29, 5.01,
#        5.88, 5.05, 5.07, 4.48, 5.49, 5.35, 5.66, 5.09, 5.63, 5.33, 6.23,
#        6.27, 6.48, 6.  , 6.93, 5.59, 6.87, 5.04, 5.39, 5.76, 4.92, 5.86,
#        5.21, 5.77, 5.26, 5.85, 5.04, 5.05, 6.51, 5.92, 6.45, 6.65, 5.53,
#        5.24, 6.48, 5.94, 5.7 , 5.5 , 5.93, 6.45, 6.58, 5.4 , 4.95, 5.19,
#        5.97, 5.37, 5.54, 5.11, 5.87, 6.68, 5.07, 6.64, 5.21, 5.45, 5.51,
#        5.77, 5.7 , 5.  , 5.25, 6.68, 5.78, 5.49, 5.5 , 5.59, 5.08, 4.99,
#        5.74, 5.78, 5.2 , 5.12, 5.11, 5.11, 6.99, 6.19, 6.1 , 5.58, 5.96,
#        5.27, 5.51, 5.9 , 6.55, 5.15, 5.34, 5.88, 6.11, 5.09, 5.96, 5.29,
#        6.29, 5.94, 5.25, 5.7 , 5.98, 6.26, 5.32, 5.65, 4.78, 5.17, 5.51,
#        6.09, 6.67, 6.27, 5.04, 6.48, 6.57, 5.5 , 6.03, 5.21, 6.86, 5.29,
#        4.9 , 5.42, 5.15, 5.51, 6.25, 5.09, 5.56, 6.86, 6.56, 5.12, 5.88,
#        4.96])

# %%
#evalute the model
mse=mean_squared_error(y_test,y_pred)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 0.3871675

# %%
#save the model
with open("wine_quality_model.pkl","wb") as f:
  pickle.dump(model,f)
